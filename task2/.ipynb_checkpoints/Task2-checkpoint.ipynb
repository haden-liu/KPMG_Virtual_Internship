# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# In C:\Users\haden\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The text.latex.preview rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\Users\haden\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The mathtext.fallback_to_cm rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\Users\haden\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle: Support for setting the 'mathtext.fallback_to_cm' rcParam is deprecated since 3.3 and will be removed two minor releases later; use 'mathtext.fallback : 'cm' instead.
# In C:\Users\haden\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The validate_bool_maybe_none function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\Users\haden\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The savefig.jpeg_quality rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\Users\haden\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The keymap.all_axes rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\Users\haden\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The animation.avconv_path rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\Users\haden\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The animation.avconv_args rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.

# %%
from matplotlib import rcParams

# %%
# load all worksheets into the notebook
df_1 = pd.read_csv("../transactions_cleansed.csv")
df_2 = pd.read_csv("../newcustomerlist_cleansed.csv")
df_3 = pd.read_csv("../customerdemographic_cleansed.csv")
df_4 = pd.read_csv("../customeraddress_cleansed.csv")

# %%
df_1.shape
# Out:
# (20000, 14)

# %%
df_2.shape
# Out:
# (1000, 18)

# %%
df_3.shape
# Out:
# (3997, 13)

# %%
df_4.shape
# Out:
# (3999, 6)

# %%
df_2.head()
# Out:
#   first_name  last_name  gender  past_3_years_bike_related_purchases  \
# 0    Chickie    Brister    Male                                   86
# 1      Morly     Genery    Male                                   69
# 2    Ardelis  Forrester  Female                                   10
# 3     Lucine      Stutt  Female                                   64
# 4    Melinda     Hadlee  Female                                   34
#
#           DOB                   job_title job_industry_category  \
# 0  1957-07-12             General Manager         Manufacturing
# 1  1970-03-22         Structural Engineer              Property
# 2  1974-08-28      Senior Cost Accountant    Financial Services
# 3  1979-01-28  Account Representative III         Manufacturing
# 4  1965-09-21           Financial Analyst    Financial Services
#
#       wealth_segment deceased_indicator owns_car  tenure              address  \
# 0      Mass Customer                  N      Yes      14     45 Shopko Center
# 1      Mass Customer                  N       No      16    14 Mccormick Park
# 2  Affluent Customer                  N       No      10  5 Colorado Crossing
# 3  Affluent Customer                  N      Yes       5   207 Annamark Plaza
# 4  Affluent Customer                  N       No      19    115 Montana Place
#
#    postcode state    country  property_valuation  Rank     Value
# 0      4500   QLD  Australia                   6     1  1.718750
# 1      2113   NSW  Australia                  11     1  1.718750
# 2      3505   VIC  Australia                   5     1  1.718750
# 3      4814   QLD  Australia                   1     4  1.703125
# 4      2093   NSW  Australia                   9     4  1.703125

# %%
df_3.head()
# Out:
#    customer_id      first_name  last_name  gender  \
# 0            1         Laraine  Medendorp  Female
# 1            2             Eli    Bockman    Male
# 2            3           Arlin     Dearle    Male
# 3            4          Talbot        NaN    Male
# 4            5  Sheila-kathryn     Calton  Female
#
#    past_3_years_bike_related_purchases         DOB               job_title  \
# 0                                   93  1953-10-12     Executive Secretary
# 1                                   81  1980-12-16  Administrative Officer
# 2                                   61  1954-01-20      Recruiting Manager
# 3                                   33  1961-10-03                     NaN
# 4                                   56  1977-05-13           Senior Editor
#
#   job_industry_category     wealth_segment deceased_indicator owns_car  \
# 0                Health      Mass Customer                  N      Yes
# 1    Financial Services      Mass Customer                  N      Yes
# 2              Property      Mass Customer                  N      Yes
# 3                    IT      Mass Customer                  N       No
# 4                   NaN  Affluent Customer                  N      Yes
#
#    tenure   age
# 0    11.0  67.0
# 1    16.0  39.0
# 2    15.0  66.0
# 3     7.0  59.0
# 4     8.0  43.0

# %%
df_1.head()
# Out:
#    transaction_id  product_id  customer_id transaction_date  online_order  \
# 0               1           2         2950       2017-02-25           0.0
# 1               2           3         3120       2017-05-21           1.0
# 2               3          37          402       2017-10-16           0.0
# 3               4          88         3135       2017-08-31           0.0
# 4               5          78          787       2017-10-01           1.0
#
#   order_status           brand product_line product_class product_size  \
# 0     Approved           Solex     Standard        medium       medium
# 1     Approved   Trek Bicycles     Standard        medium        large
# 2     Approved      OHM Cycles     Standard           low       medium
# 3     Approved  Norco Bicycles     Standard        medium       medium
# 4     Approved  Giant Bicycles     Standard        medium        large
#
#    list_price  standard_cost product_first_sold_date   profit
# 0       71.49          53.62              1970-01-01    17.87
# 1     2091.47         388.92              1970-01-01  1702.55
# 2     1793.43         248.82              1970-01-01  1544.61
# 3     1198.46         381.10              1970-01-01   817.36
# 4     1765.30         709.48              1970-01-01  1055.82

# %%
#merge customerdemographic and transactions table on customer_id
customerdemo_transaction_df = pd.merge(df_1,df_3, how = "inner", on="customer_id" )

# %%
customerdemo_transaction_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19980 entries, 0 to 19979
# Data columns (total 26 columns):
# transaction_id                         19980 non-null int64
# product_id                             19980 non-null int64
# customer_id                            19980 non-null int64
# transaction_date                       19980 non-null object
# online_order                           19620 non-null float64
# order_status                           19980 non-null object
# brand                                  19784 non-null object
# product_line                           19784 non-null object
# product_class                          19784 non-null object
# product_size                           19784 non-null object
# list_price                             19980 non-null float64
# standard_cost                          19784 non-null float64
# product_first_sold_date                19784 non-null object
# profit                                 19784 non-null float64
# first_name                             19980 non-null object
# last_name                              19338 non-null object
# gender                                 19980 non-null object
# past_3_years_bike_related_purchases    19980 non-null int64
# DOB                                    19534 non-null object
# job_title                              17586 non-null object
# job_industry_category                  16751 non-null object
# wealth_segment                         19980 non-null object
# deceased_indicator                     19980 non-null object
# owns_car                               19980 non-null object
# tenure                                 19534 non-null float64
# age                                    19534 non-null float64
# dtypes: float64(6), int64(4), object(16)
# memory usage: 4.1+ MB

# %%
customerdemo_transaction_df
# Out:
#        transaction_id  product_id  customer_id transaction_date  online_order  \
# 0                   1           2         2950       2017-02-25           0.0
# 1               11065           1         2950       2017-10-16           0.0
# 2               18923          62         2950       2017-04-26           0.0
# 3                   2           3         3120       2017-05-21           1.0
# 4                6862           4         3120       2017-10-05           0.0
# ...               ...         ...          ...              ...           ...
# 19975           19854          68          130       2017-02-02           1.0
# 19976           17966          17         2789       2017-12-06           0.0
# 19977           18462          80         2789       2017-06-20           0.0
# 19978           17981          69         3446       2017-12-26           1.0
# 19979           18165          86         3446       2017-12-03           0.0
#
#       order_status           brand product_line product_class product_size  \
# 0         Approved           Solex     Standard        medium       medium
# 1         Approved  Giant Bicycles     Standard        medium       medium
# 2         Approved           Solex     Standard        medium       medium
# 3         Approved   Trek Bicycles     Standard        medium        large
# 4         Approved  Giant Bicycles     Standard          high       medium
# ...            ...             ...          ...           ...          ...
# 19975     Approved      OHM Cycles     Standard        medium       medium
# 19976     Approved           Solex     Standard          high       medium
# 19977     Approved      OHM Cycles      Touring           low       medium
# 19978     Approved  Giant Bicycles         Road        medium       medium
# 19979     Approved      OHM Cycles     Standard        medium       medium
#
#        ...  gender  past_3_years_bike_related_purchases         DOB  \
# 0      ...    Male                                   19  1955-01-11
# 1      ...    Male                                   19  1955-01-11
# 2      ...    Male                                   19  1955-01-11
# 3      ...  Female                                   89  1979-02-04
# 4      ...  Female                                   89  1979-02-04
# ...    ...     ...                                  ...         ...
# 19975  ...    Male                                   32  1997-07-18
# 19976  ...  Female                                   66  1992-11-30
# 19977  ...  Female                                   66  1992-11-30
# 19978  ...    Male                                    8  1967-01-30
# 19979  ...    Male                                    8  1967-01-30
#
#                  job_title job_industry_category     wealth_segment  \
# 0      Software Engineer I    Financial Services      Mass Customer
# 1      Software Engineer I    Financial Services      Mass Customer
# 2      Software Engineer I    Financial Services      Mass Customer
# 3      Clinical Specialist                Health      Mass Customer
# 4      Clinical Specialist                Health      Mass Customer
# ...                    ...                   ...                ...
# 19975    Chemical Engineer         Manufacturing      Mass Customer
# 19976        Senior Editor    Financial Services  Affluent Customer
# 19977        Senior Editor    Financial Services  Affluent Customer
# 19978  Structural Engineer         Manufacturing      Mass Customer
# 19979  Structural Engineer         Manufacturing      Mass Customer
#
#       deceased_indicator  owns_car tenure   age
# 0                      N       Yes   10.0  65.0
# 1                      N       Yes   10.0  65.0
# 2                      N       Yes   10.0  65.0
# 3                      N       Yes   10.0  41.0
# 4                      N       Yes   10.0  41.0
# ...                  ...       ...    ...   ...
# 19975                  N        No    1.0  23.0
# 19976                  N       Yes    7.0  27.0
# 19977                  N       Yes    7.0  27.0
# 19978                  N        No   14.0  53.0
# 19979                  N        No   14.0  53.0
#
# [19980 rows x 26 columns]

# %%
customerdemo_transaction_df.sort_values(by='transaction_date', ascending=False)
# Out:
#        transaction_id  product_id  customer_id transaction_date  online_order  \
# 11852           13575          98         2396       2017-12-30           0.0
# 18619           13670          73         2165       2017-12-30           0.0
# 19096           16166          89         2345       2017-12-30           0.0
# 18641           15190           1          362       2017-12-30           NaN
# 368              3938          95          993       2017-12-30           0.0
# ...               ...         ...          ...              ...           ...
# 2728             3460          64          234       2017-01-01           1.0
# 5038            10003          85          467       2017-01-01           1.0
# 18519            9648          92         3056       2017-01-01           0.0
# 11918           11314           4         2068       2017-01-01           1.0
# 2444             5351          53          769       2017-01-01           1.0
#
#       order_status           brand product_line product_class product_size  \
# 11852     Approved   Trek Bicycles     Standard          high       medium
# 18619     Approved           Solex     Standard        medium       medium
# 19096     Approved        WeareA2B      Touring        medium        large
# 18641     Approved  Giant Bicycles      Touring        medium        large
# 368       Approved      OHM Cycles      Touring           low       medium
# ...            ...             ...          ...           ...          ...
# 2728      Approved  Giant Bicycles     Standard          high        small
# 5038      Approved        WeareA2B     Standard        medium       medium
# 18519     Approved        WeareA2B     Standard        medium        small
# 11918     Approved           Solex     Standard        medium       medium
# 2444      Approved      OHM Cycles     Standard        medium       medium
#
#        ...       gender  past_3_years_bike_related_purchases         DOB  \
# 11852  ...       Female                                   40  1973-08-02
# 18619  ...  Unspecified                                   16         NaN
# 19096  ...       Female                                   50  1986-07-15
# 18641  ...       Female                                   47  1974-11-17
# 368    ...       Female                                   71  1977-02-18
# ...    ...          ...                                  ...         ...
# 2728   ...       Female                                   71  1969-08-12
# 5038   ...         Male                                   51  1954-01-02
# 18519  ...       Female                                   43  1968-05-27
# 11918  ...       Female                                   23  1956-08-08
# 2444   ...         Male                                   65  1961-12-28
#
#                            job_title job_industry_category     wealth_segment  \
# 11852                      Recruiter                Retail  Affluent Customer
# 18619                 Civil Engineer         Manufacturing  Affluent Customer
# 19096        Systems Administrator I                Retail  Affluent Customer
# 18641           Software Engineer IV    Financial Services     High Net Worth
# 368              Account Coordinator           Argiculture     High Net Worth
# ...                              ...                   ...                ...
# 2728           Chief Design Engineer                Retail     High Net Worth
# 5038     Human Resources Assistant I              Property  Affluent Customer
# 18519                Health Coach II         Entertainment      Mass Customer
# 11918       Account Representative I                   NaN     High Net Worth
# 2444   Analog Circuit Design manager                    IT      Mass Customer
#
#       deceased_indicator  owns_car tenure   age
# 11852                  N       Yes    7.0  47.0
# 18619                  N        No    NaN   NaN
# 19096                  N       Yes    3.0  34.0
# 18641                  N       Yes   18.0  45.0
# 368                    N        No   17.0  43.0
# ...                  ...       ...    ...   ...
# 2728                   N        No   12.0  51.0
# 5038                   N        No   15.0  66.0
# 18519                  N        No   18.0  52.0
# 11918                  N        No    8.0  64.0
# 2444                   N        No   12.0  58.0
#
# [19980 rows x 26 columns]

# %%
customerdemo_transaction_df['transaction_date'] = pd.to_datetime(customerdemo_transaction_df['transaction_date'])

# %%
# last date of transactions
last_date = customerdemo_transaction_df['transaction_date'].max()

# %%
# find out how recent a customer purchased a product
customerdemo_transaction_df['recency_days']  = last_date - customerdemo_transaction_df['transaction_date']

# %%
customerdemo_transaction_df['transaction_date']
# Out:
# 0       2017-02-25
# 1       2017-10-16
# 2       2017-04-26
# 3       2017-05-21
# 4       2017-10-05
#            ...
# 19975   2017-02-02
# 19976   2017-12-06
# 19977   2017-06-20
# 19978   2017-12-26
# 19979   2017-12-03
# Name: transaction_date, Length: 19980, dtype: datetime64[ns]

# %%
customerdemo_transaction_df.head()
# Out:
#    transaction_id  product_id  customer_id transaction_date  online_order  \
# 0               1           2         2950       2017-02-25           0.0
# 1           11065           1         2950       2017-10-16           0.0
# 2           18923          62         2950       2017-04-26           0.0
# 3               2           3         3120       2017-05-21           1.0
# 4            6862           4         3120       2017-10-05           0.0
#
#   order_status           brand product_line product_class product_size  ...  \
# 0     Approved           Solex     Standard        medium       medium  ...
# 1     Approved  Giant Bicycles     Standard        medium       medium  ...
# 2     Approved           Solex     Standard        medium       medium  ...
# 3     Approved   Trek Bicycles     Standard        medium        large  ...
# 4     Approved  Giant Bicycles     Standard          high       medium  ...
#
#    past_3_years_bike_related_purchases         DOB            job_title  \
# 0                                   19  1955-01-11  Software Engineer I
# 1                                   19  1955-01-11  Software Engineer I
# 2                                   19  1955-01-11  Software Engineer I
# 3                                   89  1979-02-04  Clinical Specialist
# 4                                   89  1979-02-04  Clinical Specialist
#
#    job_industry_category wealth_segment deceased_indicator owns_car  tenure  \
# 0     Financial Services  Mass Customer                  N      Yes    10.0
# 1     Financial Services  Mass Customer                  N      Yes    10.0
# 2     Financial Services  Mass Customer                  N      Yes    10.0
# 3                 Health  Mass Customer                  N      Yes    10.0
# 4                 Health  Mass Customer                  N      Yes    10.0
#
#     age recency_days
# 0  65.0     308 days
# 1  65.0      75 days
# 2  65.0     248 days
# 3  41.0     223 days
# 4  41.0      86 days
#
# [5 rows x 27 columns]

# %%
# change datatype from datetime to string for splitting (next line)
customerdemo_transaction_df.dtypes
# Out:
# transaction_id                                   int64
# product_id                                       int64
# customer_id                                      int64
# transaction_date                        datetime64[ns]
# online_order                                   float64
# order_status                                    object
# brand                                           object
# product_line                                    object
# product_class                                   object
# product_size                                    object
# list_price                                     float64
# standard_cost                                  float64
# product_first_sold_date                         object
# profit                                         float64
# first_name                                      object
# last_name                                       object
# gender                                          object
# past_3_years_bike_related_purchases              int64
# DOB                                             object
# job_title                                       object
# job_industry_category                           object
# wealth_segment                                  object
# deceased_indicator                              object
# owns_car                                        object
# tenure                                         float64
# age                                            float64
# recency_days                           timedelta64[ns]
# dtype: object

# %%
customerdemo_transaction_df['recency_days'] = customerdemo_transaction_df['recency_days'].astype(str)

# %%
customerdemo_transaction_df.dtypes
# Out:
# transaction_id                                  int64
# product_id                                      int64
# customer_id                                     int64
# transaction_date                       datetime64[ns]
# online_order                                  float64
# order_status                                   object
# brand                                          object
# product_line                                   object
# product_class                                  object
# product_size                                   object
# list_price                                    float64
# standard_cost                                 float64
# product_first_sold_date                        object
# profit                                        float64
# first_name                                     object
# last_name                                      object
# gender                                         object
# past_3_years_bike_related_purchases             int64
# DOB                                            object
# job_title                                      object
# job_industry_category                          object
# wealth_segment                                 object
# deceased_indicator                             object
# owns_car                                       object
# tenure                                        float64
# age                                           float64
# recency_days                                   object
# dtype: object

# %%
customerdemo_transaction_df.head()
# Out:
#    transaction_id  product_id  customer_id transaction_date  online_order  \
# 0               1           2         2950       2017-02-25           0.0
# 1           11065           1         2950       2017-10-16           0.0
# 2           18923          62         2950       2017-04-26           0.0
# 3               2           3         3120       2017-05-21           1.0
# 4            6862           4         3120       2017-10-05           0.0
#
#   order_status           brand product_line product_class product_size  ...  \
# 0     Approved           Solex     Standard        medium       medium  ...
# 1     Approved  Giant Bicycles     Standard        medium       medium  ...
# 2     Approved           Solex     Standard        medium       medium  ...
# 3     Approved   Trek Bicycles     Standard        medium        large  ...
# 4     Approved  Giant Bicycles     Standard          high       medium  ...
#
#    past_3_years_bike_related_purchases         DOB            job_title  \
# 0                                   19  1955-01-11  Software Engineer I
# 1                                   19  1955-01-11  Software Engineer I
# 2                                   19  1955-01-11  Software Engineer I
# 3                                   89  1979-02-04  Clinical Specialist
# 4                                   89  1979-02-04  Clinical Specialist
#
#    job_industry_category wealth_segment deceased_indicator owns_car  tenure  \
# 0     Financial Services  Mass Customer                  N      Yes    10.0
# 1     Financial Services  Mass Customer                  N      Yes    10.0
# 2     Financial Services  Mass Customer                  N      Yes    10.0
# 3                 Health  Mass Customer                  N      Yes    10.0
# 4                 Health  Mass Customer                  N      Yes    10.0
#
#     age                 recency_days
# 0  65.0  308 days 00:00:00.000000000
# 1  65.0   75 days 00:00:00.000000000
# 2  65.0  248 days 00:00:00.000000000
# 3  41.0  223 days 00:00:00.000000000
# 4  41.0   86 days 00:00:00.000000000
#
# [5 rows x 27 columns]

# %%
# split so that we only take the first value
customerdemo_transaction_df['recency_days'] = customerdemo_transaction_df['recency_days'].apply(lambda x: x.split(" ")[0])

# %%
customerdemo_transaction_df.head()
# Out:
#    transaction_id  product_id  customer_id transaction_date  online_order  \
# 0               1           2         2950       2017-02-25           0.0
# 1           11065           1         2950       2017-10-16           0.0
# 2           18923          62         2950       2017-04-26           0.0
# 3               2           3         3120       2017-05-21           1.0
# 4            6862           4         3120       2017-10-05           0.0
#
#   order_status           brand product_line product_class product_size  ...  \
# 0     Approved           Solex     Standard        medium       medium  ...
# 1     Approved  Giant Bicycles     Standard        medium       medium  ...
# 2     Approved           Solex     Standard        medium       medium  ...
# 3     Approved   Trek Bicycles     Standard        medium        large  ...
# 4     Approved  Giant Bicycles     Standard          high       medium  ...
#
#    past_3_years_bike_related_purchases         DOB            job_title  \
# 0                                   19  1955-01-11  Software Engineer I
# 1                                   19  1955-01-11  Software Engineer I
# 2                                   19  1955-01-11  Software Engineer I
# 3                                   89  1979-02-04  Clinical Specialist
# 4                                   89  1979-02-04  Clinical Specialist
#
#    job_industry_category wealth_segment deceased_indicator owns_car  tenure  \
# 0     Financial Services  Mass Customer                  N      Yes    10.0
# 1     Financial Services  Mass Customer                  N      Yes    10.0
# 2     Financial Services  Mass Customer                  N      Yes    10.0
# 3                 Health  Mass Customer                  N      Yes    10.0
# 4                 Health  Mass Customer                  N      Yes    10.0
#
#     age recency_days
# 0  65.0          308
# 1  65.0           75
# 2  65.0          248
# 3  41.0          223
# 4  41.0           86
#
# [5 rows x 27 columns]

# %%
customerdemo_transaction_df.dtypes
# Out:
# transaction_id                                  int64
# product_id                                      int64
# customer_id                                     int64
# transaction_date                       datetime64[ns]
# online_order                                  float64
# order_status                                   object
# brand                                          object
# product_line                                   object
# product_class                                  object
# product_size                                   object
# list_price                                    float64
# standard_cost                                 float64
# product_first_sold_date                        object
# profit                                        float64
# first_name                                     object
# last_name                                      object
# gender                                         object
# past_3_years_bike_related_purchases             int64
# DOB                                            object
# job_title                                      object
# job_industry_category                          object
# wealth_segment                                 object
# deceased_indicator                             object
# owns_car                                       object
# tenure                                        float64
# age                                           float64
# recency_days                                   object
# dtype: object

# %%
# change datatype from datetime to float for calculations
customerdemo_transaction_df['recency_days'] = customerdemo_transaction_df['recency_days'].astype("float")

# %%
#group dataframe by customer_id
customerdemo_transaction_df.groupby(by='customer_id').sum()
# Out:
#              transaction_id  product_id  online_order  list_price  \
# customer_id
# 1                    126342         376           6.0     9084.45
# 2                     25415         112           1.0     4149.07
# 3                    110741         483           1.0     9888.23
# 4                     27089         157           1.0     1047.72
# 5                     47818         289           2.0     5903.20
# ...                     ...         ...           ...         ...
# 3496                  41277         123           3.0     4725.38
# 3497                  25695          97           2.0     3744.07
# 3498                  55965         433           5.0     5177.06
# 3499                  48099         299           4.0     7673.48
# 3500                  60456         240           2.0     4922.41
#
#              standard_cost   profit  past_3_years_bike_related_purchases  \
# customer_id
# 1                  6066.36  3018.09                                 1023
# 2                  1922.81  2226.26                                  243
# 3                  6525.42  3362.81                                  488
# 4                   827.15   220.57                                   66
# 5                  3508.26  2394.94                                  336
# ...                    ...      ...                                  ...
# 3496               2679.54  2045.84                                  396
# 3497               2095.75  1648.32                                  219
# 3498               2029.73  3147.33                                  168
# 3499               2718.23  4955.25                                  203
# 3500               3136.55  1785.86                                  426
#
#              tenure    age  recency_days
# customer_id
# 1             121.0  737.0        2204.0
# 2              48.0  117.0         570.0
# 3             120.0  528.0        1624.0
# 4              14.0  118.0         466.0
# 5              48.0  258.0        1159.0
# ...             ...    ...           ...
# 3496           76.0  136.0        1085.0
# 3497           54.0  102.0         281.0
# 3498           30.0  144.0        1456.0
# 3499           49.0  287.0        1647.0
# 3500          102.0  318.0        1709.0
#
# [3491 rows x 10 columns]

# %%
# create a count of products purchases per customer column
count_productid = customerdemo_transaction_df.groupby(by='customer_id').count()['product_id']

# %%
count_productid
# Out:
# customer_id
# 1       11
# 2        3
# 3        8
# 4        2
# 5        6
#         ..
# 3496     4
# 3497     3
# 3498     6
# 3499     7
# 3500     6
# Name: product_id, Length: 3491, dtype: int64

# %%
# create a column for the most recent time the customer purchased from Sprocket
min_transaction_days = customerdemo_transaction_df.groupby(by='customer_id')['recency_days'].min()
min_transaction_days
# Out:
# customer_id
# 1         7.0
# 2       128.0
# 3       102.0
# 4       195.0
# 5        16.0
#         ...
# 3496    256.0
# 3497     52.0
# 3498    127.0
# 3499     51.0
# 3500    144.0
# Name: recency_days, Length: 3491, dtype: float64

# %%
customerdemo_transaction_df
# Out:
#        transaction_id  product_id  customer_id transaction_date  online_order  \
# 0                   1           2         2950       2017-02-25           0.0
# 1               11065           1         2950       2017-10-16           0.0
# 2               18923          62         2950       2017-04-26           0.0
# 3                   2           3         3120       2017-05-21           1.0
# 4                6862           4         3120       2017-10-05           0.0
# ...               ...         ...          ...              ...           ...
# 19975           19854          68          130       2017-02-02           1.0
# 19976           17966          17         2789       2017-12-06           0.0
# 19977           18462          80         2789       2017-06-20           0.0
# 19978           17981          69         3446       2017-12-26           1.0
# 19979           18165          86         3446       2017-12-03           0.0
#
#       order_status           brand product_line product_class product_size  \
# 0         Approved           Solex     Standard        medium       medium
# 1         Approved  Giant Bicycles     Standard        medium       medium
# 2         Approved           Solex     Standard        medium       medium
# 3         Approved   Trek Bicycles     Standard        medium        large
# 4         Approved  Giant Bicycles     Standard          high       medium
# ...            ...             ...          ...           ...          ...
# 19975     Approved      OHM Cycles     Standard        medium       medium
# 19976     Approved           Solex     Standard          high       medium
# 19977     Approved      OHM Cycles      Touring           low       medium
# 19978     Approved  Giant Bicycles         Road        medium       medium
# 19979     Approved      OHM Cycles     Standard        medium       medium
#
#        ...  past_3_years_bike_related_purchases         DOB  \
# 0      ...                                   19  1955-01-11
# 1      ...                                   19  1955-01-11
# 2      ...                                   19  1955-01-11
# 3      ...                                   89  1979-02-04
# 4      ...                                   89  1979-02-04
# ...    ...                                  ...         ...
# 19975  ...                                   32  1997-07-18
# 19976  ...                                   66  1992-11-30
# 19977  ...                                   66  1992-11-30
# 19978  ...                                    8  1967-01-30
# 19979  ...                                    8  1967-01-30
#
#                  job_title  job_industry_category     wealth_segment  \
# 0      Software Engineer I     Financial Services      Mass Customer
# 1      Software Engineer I     Financial Services      Mass Customer
# 2      Software Engineer I     Financial Services      Mass Customer
# 3      Clinical Specialist                 Health      Mass Customer
# 4      Clinical Specialist                 Health      Mass Customer
# ...                    ...                    ...                ...
# 19975    Chemical Engineer          Manufacturing      Mass Customer
# 19976        Senior Editor     Financial Services  Affluent Customer
# 19977        Senior Editor     Financial Services  Affluent Customer
# 19978  Structural Engineer          Manufacturing      Mass Customer
# 19979  Structural Engineer          Manufacturing      Mass Customer
#
#       deceased_indicator owns_car  tenure   age recency_days
# 0                      N      Yes    10.0  65.0        308.0
# 1                      N      Yes    10.0  65.0         75.0
# 2                      N      Yes    10.0  65.0        248.0
# 3                      N      Yes    10.0  41.0        223.0
# 4                      N      Yes    10.0  41.0         86.0
# ...                  ...      ...     ...   ...          ...
# 19975                  N       No     1.0  23.0        331.0
# 19976                  N      Yes     7.0  27.0         24.0
# 19977                  N      Yes     7.0  27.0        193.0
# 19978                  N       No    14.0  53.0          4.0
# 19979                  N       No    14.0  53.0         27.0
#
# [19980 rows x 27 columns]

# %%
# find out sum of profit from each customer
sum_profit = customerdemo_transaction_df.groupby(by='customer_id').sum()['profit']
sum_profit
# Out:
# customer_id
# 1       3018.09
# 2       2226.26
# 3       3362.81
# 4        220.57
# 5       2394.94
#          ...
# 3496    2045.84
# 3497    1648.32
# 3498    3147.33
# 3499    4955.25
# 3500    1785.86
# Name: profit, Length: 3491, dtype: float64

# %%
# create a customer dataframe
customer_df = pd.DataFrame({
    "min_recency":min_transaction_days,
    "product_count":count_productid,
    "sum_profit": sum_profit
})

# %%
customer_df.head()
# Out:
#              min_recency  product_count  sum_profit
# customer_id
# 1                    7.0             11     3018.09
# 2                  128.0              3     2226.26
# 3                  102.0              8     3362.81
# 4                  195.0              2      220.57
# 5                   16.0              6     2394.94

# %% [markdown]
# # RFM Metrics

# %% [markdown]
# * recency: time since last order or last engaged with the product
# * Total number of transactions or average time between transactions/engaged visits
# * total or average transactions value

# %%
#finding IQR for recency
Q1_recency = customer_df['min_recency'].quantile(0.25)
median_recency = customer_df['min_recency'].quantile(0.5)
Q3_recency = customer_df['min_recency'].quantile(0.75)
IQR_recency = Q3_recency - Q1_recency
print(Q1_recency)
print(median_recency)
print(Q3_recency)
print(IQR_recency)
# Out:
# 17.0
# 44.0
# 85.0
# 68.0

# %%
# finding IQR for products purchased
Q1_products = customer_df['product_count'].quantile(0.25)
median_products = customer_df['product_count'].quantile(0.5)
Q3_products = customer_df['product_count'].quantile(0.75)
IQR_products = Q3_products - Q1_products
print(Q1_products)
print(median_products)
print(Q3_products)
print(IQR_products)
# Out:
# 4.0
# 6.0
# 7.0
# 3.0

# %%
# finding IQR for sum of profit
Q1_profits = customer_df['sum_profit'].quantile(0.25)
median_products = customer_df['sum_profit'].quantile(0.5)
Q3_profits = customer_df['sum_profit'].quantile(0.75)
IQR_profits = Q3_profits - Q1_profits
print(Q1_profits)
print(median_products)
print(Q3_profits)
print(IQR_profits)
# Out:
# 1841.49
# 2861.6299999999997
# 4180.254999999999
# 2338.7649999999994

# %%
# recency_score list
recency_list = []
for a in customer_df['min_recency']:
    if a <= 17:
        recency_list.append(4)
    elif a > 17 and a <= 44:
        recency_list.append(3)
    elif a > 44 and a <= 85:
        recency_list.append(2)
    else:
        recency_list.append(1)

# %%
recency_list[:5]
# Out:
# [4, 1, 1, 1, 4]

# %%
# product_score list
product_list = []
for a in customer_df['product_count']:
    if a <= 4:
        product_list.append(1)
    elif a > 4 and a <= 6:
        product_list.append(2)
    elif a > 6 and a <= 7:
        product_list.append(3)
    else:
        product_list.append(4)

# %%
product_list[:5]
# Out:
# [4, 1, 4, 1, 2]

# %%
# product_score list
profit_list = []
for a in customer_df['sum_profit']:
    if a <= 1841.73:
        profit_list.append(1)
    elif a > 1841.73 and a <= 2862.33:
        profit_list.append(2)
    elif a > 2862.33 and a <= 4183.81:
        profit_list.append(3)
    else:
        profit_list.append(4)

# %%
# insert recency score to the second column
customer_df.insert(1, "recency_score", recency_list)

# %%
customer_df.insert(3, "product_score", product_list)

# %%
customer_df['profit_score'] = profit_list

# %%
customer_df.head()
# Out:
#              min_recency  recency_score  product_count  product_score  \
# customer_id
# 1                    7.0              4             11              4
# 2                  128.0              1              3              1
# 3                  102.0              1              8              4
# 4                  195.0              1              2              1
# 5                   16.0              4              6              2
#
#              sum_profit  profit_score
# customer_id
# 1               3018.09             3
# 2               2226.26             2
# 3               3362.81             3
# 4                220.57             1
# 5               2394.94             2

# %%
customer_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3491 entries, 1 to 3500
# Data columns (total 6 columns):
# min_recency      3491 non-null float64
# recency_score    3491 non-null int64
# product_count    3491 non-null int64
# product_score    3491 non-null int64
# sum_profit       3491 non-null float64
# profit_score     3491 non-null int64
# dtypes: float64(2), int64(4)
# memory usage: 190.9 KB

# %%
",".join(map(str,customer_df[['recency_score','product_score',"profit_score"]].values.tolist()[0])).replace(",","")
# Out:
# '443'

# %%
range(customer_df.shape[0])
# Out:
# range(0, 3491)

# %%
#create loop for RFM score
RFM_score = []
for i in range(customer_df.shape[0]):
    rfm_item = customer_df[['recency_score','product_score',"profit_score"]].values.tolist()[i]
    RFM_score.append(",".join(map(str,rfm_item)).replace(",",""))

# %%
customer_df['RFM_score'] = RFM_score

# %%
customer_df.head()
# Out:
#              min_recency  recency_score  product_count  product_score  \
# customer_id
# 1                    7.0              4             11              4
# 2                  128.0              1              3              1
# 3                  102.0              1              8              4
# 4                  195.0              1              2              1
# 5                   16.0              4              6              2
#
#              sum_profit  profit_score RFM_score
# customer_id
# 1               3018.09             3       443
# 2               2226.26             2       112
# 3               3362.81             3       143
# 4                220.57             1       111
# 5               2394.94             2       422

# %%
customer_df['RFM_score'] = customer_df['RFM_score'].astype("float")

# %%
# create IQR for the RFM score
Q1_rfm = customer_df['RFM_score'].quantile(0.25)
median_rfm = customer_df['RFM_score'].quantile(0.5)
Q3_rfm = customer_df['RFM_score'].quantile(0.75)
print(Q1_rfm)
print(median_rfm)
print(Q3_rfm)
# Out:
# 211.0
# 311.0
# 411.0

# %%
customer_title = []
for j in customer_df['RFM_score']:
    if j <= 211:
        customer_title.append("Bronze")
    elif j >211 and j <=311:
        customer_title.append("Silver")
    elif j >311 and j <= 411:
        customer_title.append("Gold")
    else:
        customer_title.append("Platinum")

# %%
customer_df['customer_title'] = customer_title

# %%
customer_df.head()
# Out:
#              min_recency  recency_score  product_count  product_score  \
# customer_id
# 1                    7.0              4             11              4
# 2                  128.0              1              3              1
# 3                  102.0              1              8              4
# 4                  195.0              1              2              1
# 5                   16.0              4              6              2
#
#              sum_profit  profit_score  RFM_score customer_title
# customer_id
# 1               3018.09             3      443.0       Platinum
# 2               2226.26             2      112.0         Bronze
# 3               3362.81             3      143.0         Bronze
# 4                220.57             1      111.0         Bronze
# 5               2394.94             2      422.0       Platinum

# %%
customertitle_grouped_df = customer_df.groupby(by='customer_title').count().sort_values(by='min_recency')
customertitle_grouped_df
# Out:
#                 min_recency  recency_score  product_count  product_score  \
# customer_title
# Platinum                791            791            791            791
# Silver                  813            813            813            813
# Gold                    878            878            878            878
# Bronze                 1009           1009           1009           1009
#
#                 sum_profit  profit_score  RFM_score
# customer_title
# Platinum               791           791        791
# Silver                 813           813        813
# Gold                   878           878        878
# Bronze                1009          1009       1009

# %%
top_1000_target_df = customer_df.sort_values(by='RFM_score', ascending=False).head(1000)[['RFM_score',"customer_title"]]
top_1000_target_df.head(20)
# Out:
#              RFM_score customer_title
# customer_id
# 2182             444.0       Platinum
# 357              444.0       Platinum
# 381              444.0       Platinum
# 377              444.0       Platinum
# 2428             444.0       Platinum
# 2434             444.0       Platinum
# 2464             444.0       Platinum
# 2465             444.0       Platinum
# 2476             444.0       Platinum
# 2379             444.0       Platinum
# 2492             444.0       Platinum
# 346              444.0       Platinum
# 344              444.0       Platinum
# 2523             444.0       Platinum
# 2548             444.0       Platinum
# 2606             444.0       Platinum
# 2391             444.0       Platinum
# 2369             444.0       Platinum
# 2023             444.0       Platinum
# 2130             444.0       Platinum

# %%
customertitle_grouped_df
# Out:
#                 min_recency  recency_score  product_count  product_score  \
# customer_title
# Platinum                791            791            791            791
# Silver                  813            813            813            813
# Gold                    878            878            878            878
# Bronze                 1009           1009           1009           1009
#
#                 sum_profit  profit_score  RFM_score
# customer_title
# Platinum               791           791        791
# Silver                 813           813        813
# Gold                   878           878        878
# Bronze                1009          1009       1009

# %%
reorder_list = ['Platinum', 'Gold','Silver','Bronze']
customer_to_target_summarydf = pd.DataFrame(customertitle_grouped_df.reindex(reorder_list)['min_recency']).rename(columns={"min_recency":"count"})

# %%
customer_to_target_summarydf
# Out:
#                 count
# customer_title
# Platinum          791
# Gold              878
# Silver            813
# Bronze           1009

# %%
customer_title_descriptions = ["bought more often and spent the most",
                              "bought relatively often and spent large amount of money",
                              "average purchase frequency and average spending habits",
                              "very low recency, frequency and money spent"]

# %%
customer_to_target_summarydf.insert(0, 
                                    "title_description", 
                                    customer_title_descriptions)

# %%
customer_to_target_summarydf
# Out:
#                                                 title_description  count
# customer_title
# Platinum                     bought more often and spent the most    791
# Gold            bought relatively often and spent large amount...    878
# Silver          average purchase frequency and average spendin...    813
# Bronze                very low recency, frequency and money spent   1009

# %%
sns.set(style="whitegrid")
# create the bar chart
ax = sns.barplot(x=customertitle_grouped_df.index, y= customertitle_grouped_df['RFM_score'])
# set figsize
sns.set(rc={"figure.figsize":(20,10)})
# set plot title
ax.set_title("Customer Classes Determined With RFM Analysis", fontsize=24)
# set x axis label
ax.set_xlabel("Customer Classes", fontsize=18)
# set y axis label
ax.set_ylabel("RFM Score",fontsize=18)
# set tick font size
ax.tick_params(labelsize=15)

# %%
# recency against frequency
sns.set(style='whitegrid')
rf = sns.lmplot(x='min_recency', 
                y='product_count',
                data=customer_df,
                hue="customer_title",
                fit_reg=False,
                height=11,
                # width is calculated by: aspect*height
                aspect=22/11,
                legend_out=False)

rf.axes[0,0].set_xlabel("Recency (Days)",fontsize=18)
rf.axes[0,0].set_ylabel("Frequency of Purchase",fontsize=18)
rf.axes[0,0].set_title("Recency vs Frequency RFM Analysis", fontsize=24)

# set tick font size
rf.axes[0,0].tick_params(labelsize=15)

# set legend title,location and fontsizes
plt.legend(title='Customer Classes',
           loc='upper right',
           fontsize=18,
           title_fontsize=23)


# rf.xlabel("Recency",fontsize=18)
# rf.ylabel("Frequency",fontsize=18)
# rf.title("Recency vs Frequency RFM Analysis")
plt.tight_layout()

# %%
# Frequency vs Monetary
sns.set(style='whitegrid')
rf = sns.lmplot(x='product_count', 
                y='sum_profit',
                data=customer_df,
                hue="customer_title",
                fit_reg=False,
                height=11,
                # width is calculated by: aspect*height
                aspect=22/11,
                legend_out=False)

rf.axes[0,0].set_xlabel("Frequency of Purchase",fontsize=18)
rf.axes[0,0].set_ylabel("Monetary (Profit Values)",fontsize=18)
rf.axes[0,0].set_title("Frequency vs Monetary RFM Analysis", fontsize=24)

# set tick font size
rf.axes[0,0].tick_params(labelsize=15)

# set legend title,location and fontsizes
plt.legend(title='Customer Classes',
           loc='best',
           fontsize=18,
           title_fontsize=23)


# rf.xlabel("Recency",fontsize=18)
# rf.ylabel("Frequency",fontsize=18)
# rf.title("Recency vs Frequency RFM Analysis")
plt.tight_layout()

# %% [markdown]
# # Age group analysis

# %%
customerdemo_transaction_df.head()
# Out:
#    transaction_id  product_id  customer_id transaction_date  online_order  \
# 0               1           2         2950       2017-02-25           0.0
# 1           11065           1         2950       2017-10-16           0.0
# 2           18923          62         2950       2017-04-26           0.0
# 3               2           3         3120       2017-05-21           1.0
# 4            6862           4         3120       2017-10-05           0.0
#
#   order_status           brand product_line product_class product_size  ...  \
# 0     Approved           Solex     Standard        medium       medium  ...
# 1     Approved  Giant Bicycles     Standard        medium       medium  ...
# 2     Approved           Solex     Standard        medium       medium  ...
# 3     Approved   Trek Bicycles     Standard        medium        large  ...
# 4     Approved  Giant Bicycles     Standard          high       medium  ...
#
#    past_3_years_bike_related_purchases         DOB            job_title  \
# 0                                   19  1955-01-11  Software Engineer I
# 1                                   19  1955-01-11  Software Engineer I
# 2                                   19  1955-01-11  Software Engineer I
# 3                                   89  1979-02-04  Clinical Specialist
# 4                                   89  1979-02-04  Clinical Specialist
#
#    job_industry_category wealth_segment deceased_indicator owns_car  tenure  \
# 0     Financial Services  Mass Customer                  N      Yes    10.0
# 1     Financial Services  Mass Customer                  N      Yes    10.0
# 2     Financial Services  Mass Customer                  N      Yes    10.0
# 3                 Health  Mass Customer                  N      Yes    10.0
# 4                 Health  Mass Customer                  N      Yes    10.0
#
#     age recency_days
# 0  65.0        308.0
# 1  65.0         75.0
# 2  65.0        248.0
# 3  41.0        223.0
# 4  41.0         86.0
#
# [5 rows x 27 columns]

# %%
customerdemo_transaction_df['transaction_date'].min()
# Out:
# Timestamp('2017-01-01 00:00:00')

# %%
customerdemo_transaction_df['age'].sort_values(ascending=False)
# Out:
# 2468     89.0
# 2466     89.0
# 2475     89.0
# 2474     89.0
# 2473     89.0
#          ...
# 19471     NaN
# 19472     NaN
# 19473     NaN
# 19897     NaN
# 19898     NaN
# Name: age, Length: 19980, dtype: float64

# %%
customerdemo_transaction_df.describe()['age']
# Out:
# count    19534.000000
# mean        42.669858
# std         12.614048
# min         18.000000
# 25%         33.000000
# 50%         43.000000
# 75%         52.000000
# max         89.000000
# Name: age, dtype: float64

# %%
customerdemo_transaction_df.groupby(by='customer_id')['age'].max()
# Out:
# customer_id
# 1       67.0
# 2       39.0
# 3       66.0
# 4       59.0
# 5       43.0
#         ...
# 3496    34.0
# 3497    34.0
# 3498    24.0
# 3499    41.0
# 3500    53.0
# Name: age, Length: 3491, dtype: float64

# %%
customer_df
# Out:
#              min_recency  recency_score  product_count  product_score  \
# customer_id
# 1                    7.0              4             11              4
# 2                  128.0              1              3              1
# 3                  102.0              1              8              4
# 4                  195.0              1              2              1
# 5                   16.0              4              6              2
# ...                  ...            ...            ...            ...
# 3496               256.0              1              4              1
# 3497                52.0              2              3              1
# 3498               127.0              1              6              2
# 3499                51.0              2              7              3
# 3500               144.0              1              6              2
#
#              sum_profit  profit_score  RFM_score customer_title
# customer_id
# 1               3018.09             3      443.0       Platinum
# 2               2226.26             2      112.0         Bronze
# 3               3362.81             3      143.0         Bronze
# 4                220.57             1      111.0         Bronze
# 5               2394.94             2      422.0       Platinum
# ...                 ...           ...        ...            ...
# 3496            2045.84             2      112.0         Bronze
# 3497            1648.32             1      211.0         Bronze
# 3498            3147.33             3      123.0         Bronze
# 3499            4955.25             4      234.0         Silver
# 3500            1785.86             1      121.0         Bronze
#
# [3491 rows x 8 columns]

# %%
customer_df['age'] = customerdemo_transaction_df.groupby(by='customer_id')['age'].max()

# %%
customer_df
# Out:
#              min_recency  recency_score  product_count  product_score  \
# customer_id
# 1                    7.0              4             11              4
# 2                  128.0              1              3              1
# 3                  102.0              1              8              4
# 4                  195.0              1              2              1
# 5                   16.0              4              6              2
# ...                  ...            ...            ...            ...
# 3496               256.0              1              4              1
# 3497                52.0              2              3              1
# 3498               127.0              1              6              2
# 3499                51.0              2              7              3
# 3500               144.0              1              6              2
#
#              sum_profit  profit_score  RFM_score customer_title   age
# customer_id
# 1               3018.09             3      443.0       Platinum  67.0
# 2               2226.26             2      112.0         Bronze  39.0
# 3               3362.81             3      143.0         Bronze  66.0
# 4                220.57             1      111.0         Bronze  59.0
# 5               2394.94             2      422.0       Platinum  43.0
# ...                 ...           ...        ...            ...   ...
# 3496            2045.84             2      112.0         Bronze  34.0
# 3497            1648.32             1      211.0         Bronze  34.0
# 3498            3147.33             3      123.0         Bronze  24.0
# 3499            4955.25             4      234.0         Silver  41.0
# 3500            1785.86             1      121.0         Bronze  53.0
#
# [3491 rows x 9 columns]

# %%
bins = [customer_df['age'].min(),19,29,39,49,59,69,79,customer_df['age'].max()]
labels = ["10-19","20-29","30-39", "40-49", "50-59", "60-69", "70-79", "80+"]

# %%
customer_age_groups = pd.cut(customer_df['age'], bins, labels=labels, include_lowest=True)

# %%
customer_df['customer_age_group'] = customer_age_groups

# %%
customer_df.head()
# Out:
#              min_recency  recency_score  product_count  product_score  \
# customer_id
# 1                    7.0              4             11              4
# 2                  128.0              1              3              1
# 3                  102.0              1              8              4
# 4                  195.0              1              2              1
# 5                   16.0              4              6              2
#
#              sum_profit  profit_score  RFM_score customer_title   age  \
# customer_id
# 1               3018.09             3      443.0       Platinum  67.0
# 2               2226.26             2      112.0         Bronze  39.0
# 3               3362.81             3      143.0         Bronze  66.0
# 4                220.57             1      111.0         Bronze  59.0
# 5               2394.94             2      422.0       Platinum  43.0
#
#             customer_age_group
# customer_id
# 1                        60-69
# 2                        30-39
# 3                        60-69
# 4                        50-59
# 5                        40-49

# %%
customer_df.groupby(by="customer_age_group").count()
# Out:
#                     min_recency  recency_score  product_count  product_score  \
# customer_age_group
# 10-19                        41             41             41             41
# 20-29                       590            590            590            590
# 30-39                       606            606            606            606
# 40-49                      1175           1175           1175           1175
# 50-59                       591            591            591            591
# 60-69                       407            407            407            407
# 70-79                         2              2              2              2
# 80+                           3              3              3              3
#
#                     sum_profit  profit_score  RFM_score  customer_title   age
# customer_age_group
# 10-19                       41            41         41              41    41
# 20-29                      590           590        590             590   590
# 30-39                      606           606        606             606   606
# 40-49                     1175          1175       1175            1175  1175
# 50-59                      591           591        591             591   591
# 60-69                      407           407        407             407   407
# 70-79                        2             2          2               2     2
# 80+                          3             3          3               3     3

# %%
age_group_demographic = customer_df['customer_age_group'].value_counts().sort_index()

# %%
age_group_demographic
# Out:
# 10-19      41
# 20-29     590
# 30-39     606
# 40-49    1175
# 50-59     591
# 60-69     407
# 70-79       2
# 80+         3
# Name: customer_age_group, dtype: int64

# %%
ax = sns.barplot(x = age_group_demographic.index, y= age_group_demographic)
ax.set_title("Customer Age Groups", fontsize=20)
ax.set_xlabel("Age Groups", fontsize=15)
ax.set_ylabel("Count",fontsize=15)
ax.tick_params(labelsize=12)
rcParams['figure.figsize'] = 20,10

# set label on bars
for index, row in pd.DataFrame(age_group_demographic).reset_index().iterrows():
    ax.text(row.name,
           row.customer_age_group + 3, 
           row.customer_age_group, 
           color='black', 
           ha="center",
           fontsize=15)

# %% [markdown]
# find new customer demographics (read as df_2)

# %%
df_2.head()
# Out:
#   first_name  last_name  gender  past_3_years_bike_related_purchases  \
# 0    Chickie    Brister    Male                                   86
# 1      Morly     Genery    Male                                   69
# 2    Ardelis  Forrester  Female                                   10
# 3     Lucine      Stutt  Female                                   64
# 4    Melinda     Hadlee  Female                                   34
#
#           DOB                   job_title job_industry_category  \
# 0  1957-07-12             General Manager         Manufacturing
# 1  1970-03-22         Structural Engineer              Property
# 2  1974-08-28      Senior Cost Accountant    Financial Services
# 3  1979-01-28  Account Representative III         Manufacturing
# 4  1965-09-21           Financial Analyst    Financial Services
#
#       wealth_segment deceased_indicator owns_car  tenure              address  \
# 0      Mass Customer                  N      Yes      14     45 Shopko Center
# 1      Mass Customer                  N       No      16    14 Mccormick Park
# 2  Affluent Customer                  N       No      10  5 Colorado Crossing
# 3  Affluent Customer                  N      Yes       5   207 Annamark Plaza
# 4  Affluent Customer                  N       No      19    115 Montana Place
#
#    postcode state    country  property_valuation  Rank     Value
# 0      4500   QLD  Australia                   6     1  1.718750
# 1      2113   NSW  Australia                  11     1  1.718750
# 2      3505   VIC  Australia                   5     1  1.718750
# 3      4814   QLD  Australia                   1     4  1.703125
# 4      2093   NSW  Australia                   9     4  1.703125

# %%
df_2.dtypes
# Out:
# first_name                              object
# last_name                               object
# gender                                  object
# past_3_years_bike_related_purchases      int64
# DOB                                     object
# job_title                               object
# job_industry_category                   object
# wealth_segment                          object
# deceased_indicator                      object
# owns_car                                object
# tenure                                   int64
# address                                 object
# postcode                                 int64
# state                                   object
# country                                 object
# property_valuation                       int64
# Rank                                     int64
# Value                                  float64
# dtype: object

# %%
df_2['DOB']=pd.to_datetime(df_2['DOB'])

# %%
df_2.dtypes
# Out:
# first_name                                     object
# last_name                                      object
# gender                                         object
# past_3_years_bike_related_purchases             int64
# DOB                                    datetime64[ns]
# job_title                                      object
# job_industry_category                          object
# wealth_segment                                 object
# deceased_indicator                             object
# owns_car                                       object
# tenure                                          int64
# address                                        object
# postcode                                        int64
# state                                          object
# country                                        object
# property_valuation                              int64
# Rank                                            int64
# Value                                         float64
# dtype: object

# %%
# create a column for customer age
now = pd.Timestamp('now')
df_2['age'] = (now - df_2['DOB']).astype('<m8[Y]')

# %%
df_2.head()
# Out:
#   first_name  last_name  gender  past_3_years_bike_related_purchases  \
# 0    Chickie    Brister    Male                                   86
# 1      Morly     Genery    Male                                   69
# 2    Ardelis  Forrester  Female                                   10
# 3     Lucine      Stutt  Female                                   64
# 4    Melinda     Hadlee  Female                                   34
#
#          DOB                   job_title job_industry_category  \
# 0 1957-07-12             General Manager         Manufacturing
# 1 1970-03-22         Structural Engineer              Property
# 2 1974-08-28      Senior Cost Accountant    Financial Services
# 3 1979-01-28  Account Representative III         Manufacturing
# 4 1965-09-21           Financial Analyst    Financial Services
#
#       wealth_segment deceased_indicator owns_car  tenure              address  \
# 0      Mass Customer                  N      Yes      14     45 Shopko Center
# 1      Mass Customer                  N       No      16    14 Mccormick Park
# 2  Affluent Customer                  N       No      10  5 Colorado Crossing
# 3  Affluent Customer                  N      Yes       5   207 Annamark Plaza
# 4  Affluent Customer                  N       No      19    115 Montana Place
#
#    postcode state    country  property_valuation  Rank     Value   age
# 0      4500   QLD  Australia                   6     1  1.718750  63.0
# 1      2113   NSW  Australia                  11     1  1.718750  50.0
# 2      3505   VIC  Australia                   5     1  1.718750  46.0
# 3      4814   QLD  Australia                   1     4  1.703125  41.0
# 4      2093   NSW  Australia                   9     4  1.703125  55.0

# %%
df_2['age'].describe()
# Out:
# count    983.000000
# mean      49.023398
# std       17.086651
# min       18.000000
# 25%       37.000000
# 50%       48.000000
# 75%       63.000000
# max       82.000000
# Name: age, dtype: float64

# %%
new_customer_bins = [df_2['age'].min(), 19,29,39,49,59,69,79, df_2['age'].max()]

new_customer_labels = ["10-19","20-29","30-39", "40-49", "50-59", "60-69", "70-79", "80+"]

# %%
new_customer_age_groups = pd.cut(df_2['age'], bins=new_customer_bins, labels=new_customer_labels, include_lowest=True)

# %%
new_customer_age_groups
# Out:
# 0      60-69
# 1      50-59
# 2      40-49
# 3      40-49
# 4      50-59
#        ...
# 995    60-69
# 996    10-19
# 997    60-69
# 998    60-69
# 999    60-69
# Name: age, Length: 1000, dtype: category
# Categories (8, object): [10-19 < 20-29 < 30-39 < 40-49 < 50-59 < 60-69 < 70-79 < 80+]

# %%
df_2['customer_age_group'] = new_customer_age_groups

# %%
df_2.loc[df_2['age'] == 82]
# Out:
#     first_name   last_name  gender  past_3_years_bike_related_purchases  \
# 191   Franklin      Wohler    Male                                   55
# 265     Alleen       Eaken  Female                                   56
# 414        Wyn       Meach    Male                                   37
# 585    Letizia       Poore  Female                                   27
# 689    Willard      Booton    Male                                   69
# 769     Andrea      Pendle  Female                                   86
# 797    Anthony     Morison    Male                                    7
# 885  Zachariah  Meininking    Male                                   40
#
#            DOB            job_title job_industry_category     wealth_segment  \
# 191 1938-10-16  Clinical Specialist                Health      Mass Customer
# 265 1938-08-31                  NaN                   NaN      Mass Customer
# 414 1938-09-10                  NaN         Manufacturing      Mass Customer
# 585 1938-08-30     Web Developer II         Manufacturing  Affluent Customer
# 689 1938-09-02                  NaN                Health     High Net Worth
# 769 1938-08-05                  NaN                   NaN     High Net Worth
# 797 1938-06-08      General Manager                Health      Mass Customer
# 885 1938-06-09      Cost Accountant    Financial Services  Affluent Customer
#
#     deceased_indicator owns_car  tenure                  address  postcode  \
# 191                  N      Yes       7   6966 Delladonna Street      2250
# 265                  N       No      10      343 Lakewood Center      2089
# 414                  N       No       9    79 Armistice Junction      2765
# 585                  N       No      15      95796 Mcbride Drive      3677
# 689                  N      Yes       7    05 Ronald Regan Alley      2121
# 769                  N      Yes      13  31281 Meadow Valley Way      4500
# 797                  N       No      12         276 Derek Circle      2759
# 885                  N      Yes      20   24815 Lindbergh Avenue      2749
#
#     state    country  property_valuation  Rank     Value   age  \
# 191   NSW  Australia                   8   191  1.150000  82.0
# 265   NSW  Australia                  12   259  1.062500  82.0
# 414   NSW  Australia                   9   415  0.921875  82.0
# 585   VIC  Australia                   3   583  0.787500  82.0
# 689   NSW  Australia                   9   688  0.697000  82.0
# 769   QLD  Australia                   6   760  0.637500  82.0
# 797   NSW  Australia                   9   797  0.600000  82.0
# 885   NSW  Australia                   7   883  0.531250  82.0
#
#     customer_age_group
# 191                80+
# 265                80+
# 414                80+
# 585                80+
# 689                80+
# 769                80+
# 797                80+
# 885                80+

# %%
df_2.head()
# Out:
#   first_name  last_name  gender  past_3_years_bike_related_purchases  \
# 0    Chickie    Brister    Male                                   86
# 1      Morly     Genery    Male                                   69
# 2    Ardelis  Forrester  Female                                   10
# 3     Lucine      Stutt  Female                                   64
# 4    Melinda     Hadlee  Female                                   34
#
#          DOB                   job_title job_industry_category  \
# 0 1957-07-12             General Manager         Manufacturing
# 1 1970-03-22         Structural Engineer              Property
# 2 1974-08-28      Senior Cost Accountant    Financial Services
# 3 1979-01-28  Account Representative III         Manufacturing
# 4 1965-09-21           Financial Analyst    Financial Services
#
#       wealth_segment deceased_indicator owns_car  tenure              address  \
# 0      Mass Customer                  N      Yes      14     45 Shopko Center
# 1      Mass Customer                  N       No      16    14 Mccormick Park
# 2  Affluent Customer                  N       No      10  5 Colorado Crossing
# 3  Affluent Customer                  N      Yes       5   207 Annamark Plaza
# 4  Affluent Customer                  N       No      19    115 Montana Place
#
#    postcode state    country  property_valuation  Rank     Value   age  \
# 0      4500   QLD  Australia                   6     1  1.718750  63.0
# 1      2113   NSW  Australia                  11     1  1.718750  50.0
# 2      3505   VIC  Australia                   5     1  1.718750  46.0
# 3      4814   QLD  Australia                   1     4  1.703125  41.0
# 4      2093   NSW  Australia                   9     4  1.703125  55.0
#
#   customer_age_group
# 0              60-69
# 1              50-59
# 2              40-49
# 3              40-49
# 4              50-59

# %%
#group by age
new_age_group_demographic = df_2['customer_age_group'].value_counts().sort_index()
new_age_group_demographic
# Out:
# 10-19     13
# 20-29    169
# 30-39    103
# 40-49    229
# 50-59    174
# 60-69    172
# 70-79     89
# 80+       34
# Name: customer_age_group, dtype: int64

# %%
from matplotlib import rcParams

# %%
sns.set(style="whitegrid")
ax1 = sns.barplot(x=new_age_group_demographic.index, 
                  y=new_age_group_demographic)

ax1.set_title("New Customer Age Groups", fontsize=25)
ax1.set_xlabel("Age Groups", fontsize=18)
ax1.set_ylabel("Count",fontsize=18)
ax1.tick_params(labelsize=15)
rcParams['figure.figsize'] = 20,10

# set label on bars
for index, row in pd.DataFrame(new_age_group_demographic).reset_index().iterrows():
    ax1.text(row.name,
           row.customer_age_group + 3, 
           row.customer_age_group, 
           color='black', 
           ha="center",
           fontsize=15)

# %% [markdown]
# # Wealth Segment By Age Analysis (New vs Old Customer)

# %% [markdown]
# New Customers

# %%
df_2.head()
# Out:
#   first_name  last_name  gender  past_3_years_bike_related_purchases  \
# 0    Chickie    Brister    Male                                   86
# 1      Morly     Genery    Male                                   69
# 2    Ardelis  Forrester  Female                                   10
# 3     Lucine      Stutt  Female                                   64
# 4    Melinda     Hadlee  Female                                   34
#
#          DOB                   job_title job_industry_category  \
# 0 1957-07-12             General Manager         Manufacturing
# 1 1970-03-22         Structural Engineer              Property
# 2 1974-08-28      Senior Cost Accountant    Financial Services
# 3 1979-01-28  Account Representative III         Manufacturing
# 4 1965-09-21           Financial Analyst    Financial Services
#
#       wealth_segment deceased_indicator owns_car  tenure              address  \
# 0      Mass Customer                  N      Yes      14     45 Shopko Center
# 1      Mass Customer                  N       No      16    14 Mccormick Park
# 2  Affluent Customer                  N       No      10  5 Colorado Crossing
# 3  Affluent Customer                  N      Yes       5   207 Annamark Plaza
# 4  Affluent Customer                  N       No      19    115 Montana Place
#
#    postcode state    country  property_valuation  Rank     Value   age  \
# 0      4500   QLD  Australia                   6     1  1.718750  63.0
# 1      2113   NSW  Australia                  11     1  1.718750  50.0
# 2      3505   VIC  Australia                   5     1  1.718750  46.0
# 3      4814   QLD  Australia                   1     4  1.703125  41.0
# 4      2093   NSW  Australia                   9     4  1.703125  55.0
#
#   customer_age_group
# 0              60-69
# 1              50-59
# 2              40-49
# 3              40-49
# 4              50-59

# %%
df_2[['wealth_segment','customer_age_group']].head()
# Out:
#       wealth_segment customer_age_group
# 0      Mass Customer              60-69
# 1      Mass Customer              50-59
# 2  Affluent Customer              40-49
# 3  Affluent Customer              40-49
# 4  Affluent Customer              50-59

# %%
wealth_age_group_df = df_2.groupby(['wealth_segment','customer_age_group']).size().reset_index()
wealth_age_group_df
# Out:
#        wealth_segment customer_age_group    0
# 0   Affluent Customer              10-19    5
# 1   Affluent Customer              20-29   47
# 2   Affluent Customer              30-39   16
# 3   Affluent Customer              40-49   61
# 4   Affluent Customer              50-59   38
# 5   Affluent Customer              60-69   40
# 6   Affluent Customer              70-79   20
# 7   Affluent Customer                80+    8
# 8      High Net Worth              20-29   47
# 9      High Net Worth              30-39   32
# 10     High Net Worth              40-49   50
# 11     High Net Worth              50-59   43
# 12     High Net Worth              60-69   47
# 13     High Net Worth              70-79   24
# 14     High Net Worth                80+    6
# 15      Mass Customer              10-19    8
# 16      Mass Customer              20-29   75
# 17      Mass Customer              30-39   55
# 18      Mass Customer              40-49  118
# 19      Mass Customer              50-59   93
# 20      Mass Customer              60-69   85
# 21      Mass Customer              70-79   45
# 22      Mass Customer                80+   20

# %%
wealth_age_group_df.rename(columns={0:"count"},inplace=True)

# %%
affluent_customer_df = wealth_age_group_df.loc[wealth_age_group_df['wealth_segment']=="Affluent Customer"]
highnetworth_df = wealth_age_group_df.loc[wealth_age_group_df['wealth_segment']=="High Net Worth"]
mass_customer_df = wealth_age_group_df.loc[wealth_age_group_df['wealth_segment']=="Mass Customer"]

# %%
sns.set(style="whitegrid")
g = sns.barplot(x="customer_age_group",
               y="count",
               hue="wealth_segment",
               data = wealth_age_group_df)
# set figure size
sns.set(rc={"figure.figsize":(20,10)})

g.set_title("New Customers Wealth Segment by Age", fontsize=25)
g.set_xlabel("Age Groups", fontsize=18)
g.set_ylabel("Count",fontsize=18)

# set tick fontsize
g.tick_params(labelsize=15)
# set legend fontsize
plt.legend(fontsize=18,title_fontsize=23)

# %% [markdown]
# Old Customers

# %%
#customer demographic table
df_3.head()
# Out:
#    customer_id      first_name  last_name  gender  \
# 0            1         Laraine  Medendorp  Female
# 1            2             Eli    Bockman    Male
# 2            3           Arlin     Dearle    Male
# 3            4          Talbot        NaN    Male
# 4            5  Sheila-kathryn     Calton  Female
#
#    past_3_years_bike_related_purchases         DOB               job_title  \
# 0                                   93  1953-10-12     Executive Secretary
# 1                                   81  1980-12-16  Administrative Officer
# 2                                   61  1954-01-20      Recruiting Manager
# 3                                   33  1961-10-03                     NaN
# 4                                   56  1977-05-13           Senior Editor
#
#   job_industry_category     wealth_segment deceased_indicator owns_car  \
# 0                Health      Mass Customer                  N      Yes
# 1    Financial Services      Mass Customer                  N      Yes
# 2              Property      Mass Customer                  N      Yes
# 3                    IT      Mass Customer                  N       No
# 4                   NaN  Affluent Customer                  N      Yes
#
#    tenure   age
# 0    11.0  67.0
# 1    16.0  39.0
# 2    15.0  66.0
# 3     7.0  59.0
# 4     8.0  43.0

# %%
old_customer_agesegment_df = df_3.groupby(by=['customer_id','wealth_segment'], as_index=False).last()[['customer_id','wealth_segment','age']]

old_customer_agesegment_df.head()
# Out:
#    customer_id     wealth_segment   age
# 0            1      Mass Customer  67.0
# 1            2      Mass Customer  39.0
# 2            3      Mass Customer  66.0
# 3            4      Mass Customer  59.0
# 4            5  Affluent Customer  43.0

# %%
old_customer_bins = [old_customer_agesegment_df['age'].min(),19,29,39,49,59,69,79,old_customer_agesegment_df['age'].max()]

old_customer_labels = ["10-19","20-29","30-39", "40-49", "50-59", "60-69", "70-79", "80+"]

# %%
old_customer_age_groups = pd.cut(old_customer_agesegment_df['age'],
                                bins = old_customer_bins,
                                labels = old_customer_labels,
                                include_lowest = True)

# %%
old_customer_age_groups[:5]
# Out:
# 0    60-69
# 1    30-39
# 2    60-69
# 3    50-59
# 4    40-49
# Name: age, dtype: category
# Categories (8, object): [10-19 < 20-29 < 30-39 < 40-49 < 50-59 < 60-69 < 70-79 < 80+]

# %%
old_customer_agesegment_df['customer_age_group'] = old_customer_age_groups

# %%
old_customer_agesegment_df
# Out:
#       customer_id     wealth_segment   age customer_age_group
# 0               1      Mass Customer  67.0              60-69
# 1               2      Mass Customer  39.0              30-39
# 2               3      Mass Customer  66.0              60-69
# 3               4      Mass Customer  59.0              50-59
# 4               5  Affluent Customer  43.0              40-49
# ...           ...                ...   ...                ...
# 3992         3996      Mass Customer  45.0              40-49
# 3993         3997     High Net Worth  19.0              10-19
# 3994         3998     High Net Worth   NaN                NaN
# 3995         3999  Affluent Customer  47.0              40-49
# 3996         4000  Affluent Customer  28.0              20-29
#
# [3997 rows x 4 columns]

# %%
# group by age groups:
old_age_group_demographic = old_customer_agesegment_df['customer_age_group'].value_counts().sort_index()

# %%
pd.DataFrame(old_age_group_demographic)
# Out:
#        customer_age_group
# 10-19                  47
# 20-29                 672
# 30-39                 692
# 40-49                1336
# 50-59                 692
# 60-69                 466
# 70-79                   2
# 80+                     3

# %%
sns.set(style="whitegrid")
ax1 = sns.barplot(x=old_age_group_demographic.index, y=old_age_group_demographic)

ax1.set_title("Old Customer Age Groups", fontsize=25)
ax1.set_xlabel("Age Groups", fontsize=18)
ax1.set_ylabel("Count",fontsize=18)
ax1.tick_params(labelsize=15)
rcParams['figure.figsize'] = 20,10

# set label on bars
for index, row in pd.DataFrame(old_age_group_demographic).reset_index().iterrows():
    ax1.text(row.name,
           row.customer_age_group + 3, 
           row.customer_age_group, 
           color='black', 
           ha="center",
           fontsize=15)

# %%
old_wealth_age_group_df = old_customer_agesegment_df.groupby(by=['wealth_segment','customer_age_group']).size().reset_index().rename(columns={0:"count"})

old_wealth_age_group_df.head(6)
# Out:
#       wealth_segment customer_age_group  count
# 0  Affluent Customer              10-19     12
# 1  Affluent Customer              20-29    179
# 2  Affluent Customer              30-39    167
# 3  Affluent Customer              40-49    322
# 4  Affluent Customer              50-59    173
# 5  Affluent Customer              60-69    106

# %%
sns.set(style="whitegrid")
g = sns.barplot(x="customer_age_group",
               y="count",
               hue="wealth_segment",
               data = old_wealth_age_group_df)

sns.set(rc={"figure.figsize":(20,10)})
g.set_title("Old Customers Wealth Segment by Age", fontsize=25)
g.set_xlabel("Age Groups", fontsize=18)
g.set_ylabel("Count",fontsize=18)
g.tick_params(labelsize=15)
plt.legend(fontsize=18,title_fontsize=23)

# %% [markdown]
# # Job Industry Distribution (New vs Old Customer)
# ### New Customers

# %%
# job industry distribution
df_2.head()
# Out:
#   first_name  last_name  gender  past_3_years_bike_related_purchases  \
# 0    Chickie    Brister    Male                                   86
# 1      Morly     Genery    Male                                   69
# 2    Ardelis  Forrester  Female                                   10
# 3     Lucine      Stutt  Female                                   64
# 4    Melinda     Hadlee  Female                                   34
#
#          DOB                   job_title job_industry_category  \
# 0 1957-07-12             General Manager         Manufacturing
# 1 1970-03-22         Structural Engineer              Property
# 2 1974-08-28      Senior Cost Accountant    Financial Services
# 3 1979-01-28  Account Representative III         Manufacturing
# 4 1965-09-21           Financial Analyst    Financial Services
#
#       wealth_segment deceased_indicator owns_car  tenure              address  \
# 0      Mass Customer                  N      Yes      14     45 Shopko Center
# 1      Mass Customer                  N       No      16    14 Mccormick Park
# 2  Affluent Customer                  N       No      10  5 Colorado Crossing
# 3  Affluent Customer                  N      Yes       5   207 Annamark Plaza
# 4  Affluent Customer                  N       No      19    115 Montana Place
#
#    postcode state    country  property_valuation  Rank     Value   age  \
# 0      4500   QLD  Australia                   6     1  1.718750  63.0
# 1      2113   NSW  Australia                  11     1  1.718750  50.0
# 2      3505   VIC  Australia                   5     1  1.718750  46.0
# 3      4814   QLD  Australia                   1     4  1.703125  41.0
# 4      2093   NSW  Australia                   9     4  1.703125  55.0
#
#   customer_age_group
# 0              60-69
# 1              50-59
# 2              40-49
# 3              40-49
# 4              50-59

# %%
job_industry_category = df_2['job_industry_category'].value_counts()
job_industry_category.plot.pie(y="job_industry_category",
                               autopct="%1.2f%%",
                               fontsize=17)
plt.title("New Customer Job Industry Category Distribution", fontsize=23)
plt.ylabel("")
# Out:
# Text(0, 0.5, '')

# %% [markdown]
# #### Old Customers

# %%
customerdemo_transaction_df
# Out:
#        transaction_id  product_id  customer_id transaction_date  online_order  \
# 0                   1           2         2950       2017-02-25           0.0
# 1               11065           1         2950       2017-10-16           0.0
# 2               18923          62         2950       2017-04-26           0.0
# 3                   2           3         3120       2017-05-21           1.0
# 4                6862           4         3120       2017-10-05           0.0
# ...               ...         ...          ...              ...           ...
# 19975           19854          68          130       2017-02-02           1.0
# 19976           17966          17         2789       2017-12-06           0.0
# 19977           18462          80         2789       2017-06-20           0.0
# 19978           17981          69         3446       2017-12-26           1.0
# 19979           18165          86         3446       2017-12-03           0.0
#
#       order_status           brand product_line product_class product_size  \
# 0         Approved           Solex     Standard        medium       medium
# 1         Approved  Giant Bicycles     Standard        medium       medium
# 2         Approved           Solex     Standard        medium       medium
# 3         Approved   Trek Bicycles     Standard        medium        large
# 4         Approved  Giant Bicycles     Standard          high       medium
# ...            ...             ...          ...           ...          ...
# 19975     Approved      OHM Cycles     Standard        medium       medium
# 19976     Approved           Solex     Standard          high       medium
# 19977     Approved      OHM Cycles      Touring           low       medium
# 19978     Approved  Giant Bicycles         Road        medium       medium
# 19979     Approved      OHM Cycles     Standard        medium       medium
#
#        ...  past_3_years_bike_related_purchases         DOB  \
# 0      ...                                   19  1955-01-11
# 1      ...                                   19  1955-01-11
# 2      ...                                   19  1955-01-11
# 3      ...                                   89  1979-02-04
# 4      ...                                   89  1979-02-04
# ...    ...                                  ...         ...
# 19975  ...                                   32  1997-07-18
# 19976  ...                                   66  1992-11-30
# 19977  ...                                   66  1992-11-30
# 19978  ...                                    8  1967-01-30
# 19979  ...                                    8  1967-01-30
#
#                  job_title  job_industry_category     wealth_segment  \
# 0      Software Engineer I     Financial Services      Mass Customer
# 1      Software Engineer I     Financial Services      Mass Customer
# 2      Software Engineer I     Financial Services      Mass Customer
# 3      Clinical Specialist                 Health      Mass Customer
# 4      Clinical Specialist                 Health      Mass Customer
# ...                    ...                    ...                ...
# 19975    Chemical Engineer          Manufacturing      Mass Customer
# 19976        Senior Editor     Financial Services  Affluent Customer
# 19977        Senior Editor     Financial Services  Affluent Customer
# 19978  Structural Engineer          Manufacturing      Mass Customer
# 19979  Structural Engineer          Manufacturing      Mass Customer
#
#       deceased_indicator owns_car  tenure   age recency_days
# 0                      N      Yes    10.0  65.0        308.0
# 1                      N      Yes    10.0  65.0         75.0
# 2                      N      Yes    10.0  65.0        248.0
# 3                      N      Yes    10.0  41.0        223.0
# 4                      N      Yes    10.0  41.0         86.0
# ...                  ...      ...     ...   ...          ...
# 19975                  N       No     1.0  23.0        331.0
# 19976                  N      Yes     7.0  27.0         24.0
# 19977                  N      Yes     7.0  27.0        193.0
# 19978                  N       No    14.0  53.0          4.0
# 19979                  N       No    14.0  53.0         27.0
#
# [19980 rows x 27 columns]

# %%
# job industry distribution
job_industry_category_2 = customerdemo_transaction_df['job_industry_category'].value_counts()

job_industry_category_2.plot.pie(y="job_industry_category",
                               autopct="%1.2f%%",
                              fontsize=17)

plt.title("Old Customer Job Industry Category Distribution", fontsize=23)
plt.ylabel("")
# Out:
# Text(0, 0.5, '')

# %% [markdown]
# ## Bike related purchases for the past 3 years by gender

# %%
df_2.head()
# Out:
#   first_name  last_name  gender  past_3_years_bike_related_purchases  \
# 0    Chickie    Brister    Male                                   86
# 1      Morly     Genery    Male                                   69
# 2    Ardelis  Forrester  Female                                   10
# 3     Lucine      Stutt  Female                                   64
# 4    Melinda     Hadlee  Female                                   34
#
#          DOB                   job_title job_industry_category  \
# 0 1957-07-12             General Manager         Manufacturing
# 1 1970-03-22         Structural Engineer              Property
# 2 1974-08-28      Senior Cost Accountant    Financial Services
# 3 1979-01-28  Account Representative III         Manufacturing
# 4 1965-09-21           Financial Analyst    Financial Services
#
#       wealth_segment deceased_indicator owns_car  tenure              address  \
# 0      Mass Customer                  N      Yes      14     45 Shopko Center
# 1      Mass Customer                  N       No      16    14 Mccormick Park
# 2  Affluent Customer                  N       No      10  5 Colorado Crossing
# 3  Affluent Customer                  N      Yes       5   207 Annamark Plaza
# 4  Affluent Customer                  N       No      19    115 Montana Place
#
#    postcode state    country  property_valuation  Rank     Value   age  \
# 0      4500   QLD  Australia                   6     1  1.718750  63.0
# 1      2113   NSW  Australia                  11     1  1.718750  50.0
# 2      3505   VIC  Australia                   5     1  1.718750  46.0
# 3      4814   QLD  Australia                   1     4  1.703125  41.0
# 4      2093   NSW  Australia                   9     4  1.703125  55.0
#
#   customer_age_group
# 0              60-69
# 1              50-59
# 2              40-49
# 3              40-49
# 4              50-59

# %%
df_2['past_3_years_bike_related_purchases'].sum()
# Out:
# 49836

# %%
df_2.groupby(by='gender').sum()['past_3_years_bike_related_purchases']
# Out:
# gender
# Female         25212
# Male           23765
# Unspecified      859
# Name: past_3_years_bike_related_purchases, dtype: int64

# %%
# past 3 years purchases by gender
colors = ['lightskyblue','gold',"lightgreen"]

# define function that displays percentage and numeric value
def make_autopct(values):
    def my_autopct(pct):
        total = sum(values)
        val = int(round(pct*total/100.0))
        return '{p:.2f}%  ({v:d})'.format(p=pct,v=val)
    return my_autopct

new_past_three_years = df_2.groupby(by='gender').sum()['past_3_years_bike_related_purchases']
new_past_three_years.plot.pie(y="past_3_years_bike_related_purchases",
                              autopct=make_autopct(new_past_three_years.values),
                              startangle=120,
                              colors=colors,
                             fontsize=17)
plt.title("new customer total bike related purchases for the past 3 years by gender".title(), fontsize=25)
plt.ylabel("")
# Out:
# Text(0, 0.5, '')

# %% [markdown]
# ## Car Ownership by State (New vs Old Customer)
# #### New Customers

# %%
df_2.head()
# Out:
#   first_name  last_name  gender  past_3_years_bike_related_purchases  \
# 0    Chickie    Brister    Male                                   86
# 1      Morly     Genery    Male                                   69
# 2    Ardelis  Forrester  Female                                   10
# 3     Lucine      Stutt  Female                                   64
# 4    Melinda     Hadlee  Female                                   34
#
#          DOB                   job_title job_industry_category  \
# 0 1957-07-12             General Manager         Manufacturing
# 1 1970-03-22         Structural Engineer              Property
# 2 1974-08-28      Senior Cost Accountant    Financial Services
# 3 1979-01-28  Account Representative III         Manufacturing
# 4 1965-09-21           Financial Analyst    Financial Services
#
#       wealth_segment deceased_indicator owns_car  tenure              address  \
# 0      Mass Customer                  N      Yes      14     45 Shopko Center
# 1      Mass Customer                  N       No      16    14 Mccormick Park
# 2  Affluent Customer                  N       No      10  5 Colorado Crossing
# 3  Affluent Customer                  N      Yes       5   207 Annamark Plaza
# 4  Affluent Customer                  N       No      19    115 Montana Place
#
#    postcode state    country  property_valuation  Rank     Value   age  \
# 0      4500   QLD  Australia                   6     1  1.718750  63.0
# 1      2113   NSW  Australia                  11     1  1.718750  50.0
# 2      3505   VIC  Australia                   5     1  1.718750  46.0
# 3      4814   QLD  Australia                   1     4  1.703125  41.0
# 4      2093   NSW  Australia                   9     4  1.703125  55.0
#
#   customer_age_group
# 0              60-69
# 1              50-59
# 2              40-49
# 3              40-49
# 4              50-59

# %%
df_2[['state','owns_car',"first_name"]].sort_values(by='state')
# Out:
#     state owns_car first_name
# 999   NSW      Yes      Sylas
# 391   NSW       No      Tamar
# 719   NSW      Yes  Inglebert
# 389   NSW       No       Fara
# 720   NSW       No    Brendis
# ..    ...      ...        ...
# 352   VIC      Yes    Delinda
# 354   VIC      Yes  Giulietta
# 356   VIC      Yes      Brynn
# 359   VIC       No       Pace
# 796   VIC      Yes      Amara
#
# [1000 rows x 3 columns]

# %%
state_owncar_df = df_2[['state','owns_car',"first_name"]].groupby(["state",'owns_car'],as_index=False).count()
state_owncar_df
# Out:
#   state owns_car  first_name
# 0   NSW       No         272
# 1   NSW      Yes         234
# 2   QLD       No         103
# 3   QLD      Yes         125
# 4   VIC       No         132
# 5   VIC      Yes         134

# %%
state_owncar_df.loc[state_owncar_df['state']=="NSW","first_name"].sum()
# Out:
# 506

# %%
state_owncar_df['first_name'][0]
# Out:
# 272

# %%
NSW_sum = state_owncar_df.loc[state_owncar_df['state']=="NSW","first_name"].sum()
QLD_sum = state_owncar_df.loc[state_owncar_df['state']=="QLD","first_name"].sum()
VIC_sum = state_owncar_df.loc[state_owncar_df['state']=="VIC","first_name"].sum()

# %%
car_ownership_percentage = []
for i in range(state_owncar_df.shape[0]):
    if state_owncar_df['state'][i] == "NSW":
        some_percentage = round((state_owncar_df['first_name'][i] / NSW_sum * 100),2)
        car_ownership_percentage.append(some_percentage)
    elif state_owncar_df['state'][i] == "QLD":
        some_percentage = round((state_owncar_df['first_name'][i] / QLD_sum * 100),2)
        car_ownership_percentage.append(some_percentage)
    else:
        some_percentage = round((state_owncar_df['first_name'][i] / VIC_sum * 100),2)
        car_ownership_percentage.append(some_percentage)

# %%
car_ownership_percentage
# Out:
# [53.75, 46.25, 45.18, 54.82, 49.62, 50.38]

# %%
state_owncar_df['percentage'] = car_ownership_percentage

# %%
state_owncar_df
# Out:
#   state owns_car  first_name  percentage
# 0   NSW       No         272       53.75
# 1   NSW      Yes         234       46.25
# 2   QLD       No         103       45.18
# 3   QLD      Yes         125       54.82
# 4   VIC       No         132       49.62
# 5   VIC      Yes         134       50.38

# %%
sns.set(style='whitegrid')
state_owncar_graph = sns.barplot(x="owns_car",
                                 y='first_name',
                                 data=state_owncar_df,
                                 hue='state')
sns.set(rc={"figure.figsize":(22,11)})
state_owncar_graph.set_title("number of car owners in each state for new customers".title(),fontsize=24)
state_owncar_graph.set_xlabel("Owns Car",fontsize=18)
state_owncar_graph.set_ylabel("Count",fontsize=18)
state_owncar_graph.tick_params(labelsize=15)
plt.legend(fontsize=18,title_fontsize=23)

# %% [markdown]
# #### Old Customers

# %%
customerdemo_transaction_df.head()
# Out:
#    transaction_id  product_id  customer_id transaction_date  online_order  \
# 0               1           2         2950       2017-02-25           0.0
# 1           11065           1         2950       2017-10-16           0.0
# 2           18923          62         2950       2017-04-26           0.0
# 3               2           3         3120       2017-05-21           1.0
# 4            6862           4         3120       2017-10-05           0.0
#
#   order_status           brand product_line product_class product_size  ...  \
# 0     Approved           Solex     Standard        medium       medium  ...
# 1     Approved  Giant Bicycles     Standard        medium       medium  ...
# 2     Approved           Solex     Standard        medium       medium  ...
# 3     Approved   Trek Bicycles     Standard        medium        large  ...
# 4     Approved  Giant Bicycles     Standard          high       medium  ...
#
#    past_3_years_bike_related_purchases         DOB            job_title  \
# 0                                   19  1955-01-11  Software Engineer I
# 1                                   19  1955-01-11  Software Engineer I
# 2                                   19  1955-01-11  Software Engineer I
# 3                                   89  1979-02-04  Clinical Specialist
# 4                                   89  1979-02-04  Clinical Specialist
#
#    job_industry_category wealth_segment deceased_indicator owns_car  tenure  \
# 0     Financial Services  Mass Customer                  N      Yes    10.0
# 1     Financial Services  Mass Customer                  N      Yes    10.0
# 2     Financial Services  Mass Customer                  N      Yes    10.0
# 3                 Health  Mass Customer                  N      Yes    10.0
# 4                 Health  Mass Customer                  N      Yes    10.0
#
#     age recency_days
# 0  65.0        308.0
# 1  65.0         75.0
# 2  65.0        248.0
# 3  41.0        223.0
# 4  41.0         86.0
#
# [5 rows x 27 columns]

# %%
df_4.head()
# Out:
#    customer_id              address  postcode state    country  \
# 0            1   060 Morning Avenue      2016   NSW  Australia
# 1            2  6 Meadow Vale Court      2153   NSW  Australia
# 2            4   0 Holy Cross Court      4211   QLD  Australia
# 3            5  17979 Del Mar Point      2448   NSW  Australia
# 4            6     9 Oakridge Court      3216   VIC  Australia
#
#    property_valuation
# 0                  10
# 1                  10
# 2                   9
# 3                   4
# 4                   9

# %%
bins = [customerdemo_transaction_df['age'].min(), 19,29,39,49,59,69,79,customerdemo_transaction_df['age'].max()]
labels = ["10-19","20-29","30-39", "40-49", "50-59", "60-69", "70-79", "80+"]

# %%
customer_age_group = pd.cut(customerdemo_transaction_df['age'],
                       bins=bins,
                       labels=labels,
                       include_lowest=True)

# %%
customerdemo_transaction_df['customer_age_group'] = customer_age_group

# %%
# get the state from the customerAddress worksheet
complete_old_customer_df = pd.merge(customerdemo_transaction_df, 
                                     df_4, 
                                     how="inner",
                                     on = "customer_id")

# %%
complete_old_customer_df['state'].unique()
# Out:
# array(['VIC', 'NSW', 'QLD'], dtype=object)

# %%
complete_old_customer_df[['state','owns_car','first_name']].sort_values(by='state')
# Out:
#       state owns_car first_name
# 9975    NSW       No      Dyann
# 15129   NSW       No  Elbertine
# 15128   NSW       No  Elbertine
# 15127   NSW       No  Elbertine
# 15126   NSW       No  Elbertine
# ...     ...      ...        ...
# 15419   VIC      Yes       Bert
# 15418   VIC      Yes       Bert
# 7287    VIC       No     Mahmud
# 15443   VIC      Yes      Phebe
# 0       VIC      Yes    Kristos
#
# [19951 rows x 3 columns]

# %%
old_stateowncar_df = complete_old_customer_df[['state','owns_car','first_name']].groupby(['state','owns_car'],as_index=False).count()
old_stateowncar_df
# Out:
#   state owns_car  first_name
# 0   NSW       No        5201
# 1   NSW      Yes        5476
# 2   QLD       No        2120
# 3   QLD      Yes        2133
# 4   VIC       No        2596
# 5   VIC      Yes        2425

# %%
sns.set(style='whitegrid')
state_owncar_graph = sns.barplot(x="owns_car",
                                 y='first_name',
                                 data=old_stateowncar_df,
                                 hue='state')
sns.set(rc={"figure.figsize":(22,11)})
state_owncar_graph.set_title("number of car owners in each state for old customers".title(),fontsize=24)
state_owncar_graph.set_xlabel("Owns Car",fontsize=18)
state_owncar_graph.set_ylabel("Count",fontsize=18)
state_owncar_graph.tick_params(labelsize=15)
plt.legend(fontsize=18,title_fontsize=23)

# %%
customer_title_column = pd.DataFrame(customer_df['customer_title'])
customer_title_column
# Out:
#             customer_title
# customer_id
# 1                 Platinum
# 2                   Bronze
# 3                   Bronze
# 4                   Bronze
# 5                 Platinum
# ...                    ...
# 3496                Bronze
# 3497                Bronze
# 3498                Bronze
# 3499                Silver
# 3500                Bronze
#
# [3491 rows x 1 columns]

# %%
complete_old_customer_df = pd.merge(complete_old_customer_df,customer_title_column,how='inner',on='customer_id')

# %%
complete_old_customer_df
# Out:
#        transaction_id  product_id  customer_id transaction_date  online_order  \
# 0                   1           2         2950       2017-02-25           0.0
# 1               11065           1         2950       2017-10-16           0.0
# 2               18923          62         2950       2017-04-26           0.0
# 3                   2           3         3120       2017-05-21           1.0
# 4                6862           4         3120       2017-10-05           0.0
# ...               ...         ...          ...              ...           ...
# 19946           19854          68          130       2017-02-02           1.0
# 19947           17966          17         2789       2017-12-06           0.0
# 19948           18462          80         2789       2017-06-20           0.0
# 19949           17981          69         3446       2017-12-26           1.0
# 19950           18165          86         3446       2017-12-03           0.0
#
#       order_status           brand product_line product_class product_size  \
# 0         Approved           Solex     Standard        medium       medium
# 1         Approved  Giant Bicycles     Standard        medium       medium
# 2         Approved           Solex     Standard        medium       medium
# 3         Approved   Trek Bicycles     Standard        medium        large
# 4         Approved  Giant Bicycles     Standard          high       medium
# ...            ...             ...          ...           ...          ...
# 19946     Approved      OHM Cycles     Standard        medium       medium
# 19947     Approved           Solex     Standard          high       medium
# 19948     Approved      OHM Cycles      Touring           low       medium
# 19949     Approved  Giant Bicycles         Road        medium       medium
# 19950     Approved      OHM Cycles     Standard        medium       medium
#
#        ...  tenure   age recency_days  customer_age_group            address  \
# 0      ...    10.0  65.0        308.0               60-69  984 Hoepker Court
# 1      ...    10.0  65.0         75.0               60-69  984 Hoepker Court
# 2      ...    10.0  65.0        248.0               60-69  984 Hoepker Court
# 3      ...    10.0  41.0        223.0               40-49    4 Shopko Circle
# 4      ...    10.0  41.0         86.0               40-49    4 Shopko Circle
# ...    ...     ...   ...          ...                 ...                ...
# 19946  ...     1.0  23.0        331.0               20-29     58 Helena Hill
# 19947  ...     7.0  27.0         24.0               20-29      724 West Park
# 19948  ...     7.0  27.0        193.0               20-29      724 West Park
# 19949  ...    14.0  53.0          4.0               50-59     8 Becker Drive
# 19950  ...    14.0  53.0         27.0               50-59     8 Becker Drive
#
#       postcode state    country property_valuation customer_title
# 0         3064   VIC  Australia                  6         Bronze
# 1         3064   VIC  Australia                  6         Bronze
# 2         3064   VIC  Australia                  6         Bronze
# 3         2196   NSW  Australia                  5           Gold
# 4         2196   NSW  Australia                  5           Gold
# ...        ...   ...        ...                ...            ...
# 19946     2205   NSW  Australia                  7         Bronze
# 19947     2112   NSW  Australia                 11         Silver
# 19948     2112   NSW  Australia                 11         Silver
# 19949     4868   QLD  Australia                  4           Gold
# 19950     4868   QLD  Australia                  4           Gold
#
# [19951 rows x 34 columns]

# %%
tenure_column = pd.DataFrame(complete_old_customer_df.groupby(by='customer_id').last()['tenure'])

# %%
customer_df = pd.merge(customer_df,tenure_column,how='inner',on='customer_id')

# %%
customer_df.head()
# Out:
#              min_recency  recency_score  product_count  product_score  \
# customer_id
# 1                    7.0              4             11              4
# 2                  128.0              1              3              1
# 4                  195.0              1              2              1
# 5                   16.0              4              6              2
# 6                   64.0              2              5              2
#
#              sum_profit  profit_score  RFM_score customer_title   age  \
# customer_id
# 1               3018.09             3      443.0       Platinum  67.0
# 2               2226.26             2      112.0         Bronze  39.0
# 4                220.57             1      111.0         Bronze  59.0
# 5               2394.94             2      422.0       Platinum  43.0
# 6               3946.55             3      223.0         Silver  54.0
#
#             customer_age_group  tenure
# customer_id
# 1                        60-69    11.0
# 2                        30-39    16.0
# 4                        50-59     7.0
# 5                        40-49     8.0
# 6                        50-59    13.0

# %%
complete_old_customer_df.to_csv("complete_old_customer_df2.csv",index=False)

# %%
# add a tenure column to the customer_df
tenure_column = pd.DataFrame(complete_old_customer_df.groupby(by='customer_id').last()['tenure'])

# %%
customer_df = pd.merge(customer_df,tenure_column,how='inner',on='customer_id')

# %%
customer_df.head()
# Out:
#              min_recency  recency_score  product_count  product_score  \
# customer_id
# 1                    7.0              4             11              4
# 2                  128.0              1              3              1
# 4                  195.0              1              2              1
# 5                   16.0              4              6              2
# 6                   64.0              2              5              2
#
#              sum_profit  profit_score  RFM_score customer_title   age  \
# customer_id
# 1               3018.09             3      443.0       Platinum  67.0
# 2               2226.26             2      112.0         Bronze  39.0
# 4                220.57             1      111.0         Bronze  59.0
# 5               2394.94             2      422.0       Platinum  43.0
# 6               3946.55             3      223.0         Silver  54.0
#
#             customer_age_group  tenure_x  tenure_y
# customer_id
# 1                        60-69      11.0      11.0
# 2                        30-39      16.0      16.0
# 4                        50-59       7.0       7.0
# 5                        40-49       8.0       8.0
# 6                        50-59      13.0      13.0

# %%
customer_df.to_csv("customer_df.csv")
